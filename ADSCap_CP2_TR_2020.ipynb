# %% [markdown]
# # Segmentation and Clustering the Neighborhoods in Toronto City

# %% [markdown]
# ## 1. Before we start to collect the data and exploring it, let's download all the dependencies that we will need.

# %%
pip install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Downloading https://files.pythonhosted.org/packages/66/25/ff030e2437265616a1e9b25ccc864e0371a0bc3adb7c5a404fd661c6f4f6/beautifulsoup4-4.9.1-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 8.8MB/s eta 0:00:01
# Collecting soupsieve>1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/6f/8f/457f4a5390eeae1cc3aeab89deb7724c965be841ffca6cfca9197482e470/soupsieve-2.0.1-py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.9.1 bs4-0.0.1 soupsieve-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/55/6f/c87dffdd88a54dd26a3a9fef1d14b6384a9933c455c54ce3ca7d64a84c88/lxml-4.5.1-cp36-cp36m-manylinux1_x86_64.whl (5.5MB)
#      |████████████████████████████████| 5.5MB 5.3MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.5.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Note: We might need to restart the kernel to use updated packages.**

# %%
from bs4 import BeautifulSoup

import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.22.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.1               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.9.2         |   py36h45558ae_0         613 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.0.3               |   py36h830a2c2_1        11.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.1-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.9.2-py36h45558ae_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.9-py_1
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.3-py36h830a2c2_1
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   requests           conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.9-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
#
#
# Downloading and Extracting Packages
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# branca-0.4.1         | 26 KB     | ##################################### | 100%
# cryptography-2.9.2   | 613 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# pandas-1.0.3         | 11.1 MB   | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# ## 2. Scrape and extract the relevant dataset (Postal Code, Borough and Neighborhood) of the neighborhoods in Toronto City from Wikipedia webpage and transform the dataset into a *pandas* dataframe

# %% [markdown]
# #### Scraping the relevant data from webpage

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
result = requests.get(url).text
Canada_data = BeautifulSoup(result, 'lxml')

# %% [markdown]
# #### Transform the Toronto City data into dataframe

# %%
# define the dataframe columns
column_names = ['PostalCode','Borough','Neighborhood']

# instantiate the dataframe
toronto = pd.DataFrame(columns = column_names)


# loop through to find postcode, borough, neighborhood 
content = Canada_data.find('div', class_='mw-parser-output')
table = content.table.tbody
postcode = 0
borough = 0
neighborhood = 0

for tr in table.find_all('tr'):
    i = 0
    for td in tr.find_all('td'):
        if i == 0:
            postcode = td.text
            i = i + 1
        elif i == 1:
            borough = td.text
            i = i + 1
        elif i == 2: 
            neighborhood = td.text.strip('\n').replace(']','')
    toronto = toronto.append({'PostalCode': postcode,'Borough': borough,'Neighborhood': neighborhood},ignore_index=True)

# %% [markdown]
# #### Clean the dataframe

# %%
# clean dataframe 
toronto = toronto[toronto.Borough!='Not assigned']
toronto = toronto[toronto.Borough!= 0]
toronto.reset_index(drop = True, inplace = True)
i = 0
for i in range(0,toronto.shape[0]):
    if toronto.iloc[i][2] == 'Not assigned':
        toronto.iloc[i][2] = toronto.iloc[i][1]
        i = i+1
                                 
df = toronto.groupby(['PostalCode','Borough'])['Neighborhood'].apply(', '.join).reset_index()

df['PostalCode']=df['PostalCode'].str.replace("\n","")
df['Borough']=df['Borough'].str.replace("\n","")
df['Neighborhood']=df['Neighborhood'].str.replace("/",",")
df = df.dropna()
empty = 'Not assigned'
df = df[(df.PostalCode != empty ) & (df.Borough != empty) & (df.Neighborhood != empty)]
df.rename(columns={'PostalCode':'Postal Code'}, inplace=True)
df.head()
# Out:
#   Postal Code      Borough                            Neighborhood
# 1         M1B  Scarborough                          Malvern, Rouge
# 2         M1C  Scarborough  Rouge Hill, Port Union, Highland Creek
# 3         M1E  Scarborough       Guildwood, Morningside, West Hill
# 4         M1G  Scarborough                                  Woburn
# 5         M1H  Scarborough                               Cedarbrae

# %% [markdown]
# #### Download the geological coordinates data and read into the cleaned dataframe

# %%
toronto_geocsv = 'https://cocl.us/Geospatial_data'
# !wget -q -O 'toronto_m.geospatial_data.csv' toronto_geocsv
geocsv_data = pd.read_csv(toronto_geocsv).set_index("Postal Code")

df = pd.merge(geocsv_data, df, on='Postal Code')
df = df[['Postal Code', 'Borough', 'Neighborhood', 'Latitude', 'Longitude']]
df.head(11)
# Out:
#    Postal Code      Borough  \
# 0          M1B  Scarborough
# 1          M1C  Scarborough
# 2          M1E  Scarborough
# 3          M1G  Scarborough
# 4          M1H  Scarborough
# 5          M1J  Scarborough
# 6          M1K  Scarborough
# 7          M1L  Scarborough
# 8          M1M  Scarborough
# 9          M1N  Scarborough
# 10         M1P  Scarborough
#
#                                          Neighborhood   Latitude  Longitude
# 0                                      Malvern, Rouge  43.806686 -79.194353
# 1              Rouge Hill, Port Union, Highland Creek  43.784535 -79.160497
# 2                   Guildwood, Morningside, West Hill  43.763573 -79.188711
# 3                                              Woburn  43.770992 -79.216917
# 4                                           Cedarbrae  43.773136 -79.239476
# 5                                 Scarborough Village  43.744734 -79.239476
# 6         Kennedy Park, Ionview, East Birchmount Park  43.727929 -79.262029
# 7                     Golden Mile, Clairlea, Oakridge  43.711112 -79.284577
# 8     Cliffside, Cliffcrest, Scarborough Village West  43.716316 -79.239476
# 9                         Birch Cliff, Cliffside West  43.692657 -79.264848
# 10  Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304

# %% [markdown]
# #### Downtown Toronto is selected for this project in the Toronto City

# %%
df_3=df[df['Borough'].str.contains('Downtown Toronto')]

df_3=df[df['Borough'].str.contains('Downtown Toronto')].reset_index(drop=True)
print(df_3.shape)
df_3
# Out:
# (19, 5)
#    Postal Code           Borough  \
# 0          M4W  Downtown Toronto
# 1          M4X  Downtown Toronto
# 2          M4Y  Downtown Toronto
# 3          M5A  Downtown Toronto
# 4          M5B  Downtown Toronto
# 5          M5C  Downtown Toronto
# 6          M5E  Downtown Toronto
# 7          M5G  Downtown Toronto
# 8          M5H  Downtown Toronto
# 9          M5J  Downtown Toronto
# 10         M5K  Downtown Toronto
# 11         M5L  Downtown Toronto
# 12         M5S  Downtown Toronto
# 13         M5T  Downtown Toronto
# 14         M5V  Downtown Toronto
# 15         M5W  Downtown Toronto
# 16         M5X  Downtown Toronto
# 17         M6G  Downtown Toronto
# 18         M7A  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 0                                            Rosedale  43.679563 -79.377529
# 1                         St. James Town, Cabbagetown  43.667967 -79.367675
# 2                                Church and Wellesley  43.665860 -79.383160
# 3                           Regent Park, Harbourfront  43.654260 -79.360636
# 4                            Garden District, Ryerson  43.657162 -79.378937
# 5                                      St. James Town  43.651494 -79.375418
# 6                                         Berczy Park  43.644771 -79.373306
# 7                                  Central Bay Street  43.657952 -79.387383
# 8                            Richmond, Adelaide, King  43.650571 -79.384568
# 9   Harbourfront East, Union Station, Toronto Islands  43.640816 -79.381752
# 10           Toronto Dominion Centre, Design Exchange  43.647177 -79.381576
# 11                     Commerce Court, Victoria Hotel  43.648198 -79.379817
# 12                     University of Toronto, Harbord  43.662696 -79.400049
# 13          Kensington Market, Chinatown, Grange Park  43.653206 -79.400049
# 14  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 15                                     Stn A PO Boxes  43.646435 -79.374846
# 16             First Canadian Place, Underground city  43.648429 -79.382280
# 17                                           Christie  43.669542 -79.422564
# 18        Queen's Park, Ontario Provincial Government  43.662301 -79.389494

# %% [markdown]
# ## 3. Use the Foursquare API to explore neighbourhoods in Downtown Toronto, Toronto City

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Downtown Toronto, Toronto City, then visualize Downtown Toronto with the neighbourhoods in it by creating a map using **Folium**

# %%
address = 'Downtown Toronto, Toronto'

geolocator = Nominatim(user_agent="tr_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))

# create map of Downtown Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_3['Latitude'], df_3['Longitude'], df_3['Borough'], df_3['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6541737, -79.38081164513409.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### **PLEASE VIEW THE VISUALIZED MAP BY DROP THE GITHUB LINK TO THIS .ipynb FILE INTO https://nbviewer.jupyter.org/**

# %% [markdown]
# #### Define Foursquare Credentials and Version.

# %%
CLIENT_ID = 'QR24W0AJYVEDYGP3OAWVWXEGVBW1X2NYSY5ZM0WW34I10AF2' # your Foursquare ID
CLIENT_SECRET = 'MMSVAVCUUGDAQKKD3R2HLDI4OMUEUCZVGUCCGUREXKY34WTZ' # your Foursquare Secret
VERSION = '20200516'

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QR24W0AJYVEDYGP3OAWVWXEGVBW1X2NYSY5ZM0WW34I10AF2
# CLIENT_SECRET:MMSVAVCUUGDAQKKD3R2HLDI4OMUEUCZVGUCCGUREXKY34WTZ

# %% [markdown]
# #### Explore the neighborhoods in Downtown Toronto. Create GET request URL, send the GET request, then clean and structure json into a new dataframe

# %%
# The following function retrieves the venues given the names and coordinates and stores it into dataframe.
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        LIMIT = 30
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

toronto_venues = getNearbyVenues(names=df_3['Neighborhood'],
                                   latitudes=df_3['Latitude'],
                                   longitudes=df_3['Longitude']
                                  )
# Out:
# Rosedale
# St. James Town, Cabbagetown
# Church and Wellesley
# Regent Park, Harbourfront
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Richmond, Adelaide, King
# Harbourfront East, Union Station, Toronto Islands
# Toronto Dominion Centre, Design Exchange
# Commerce Court, Victoria Hotel
# University of Toronto, Harbord
# Kensington Market, Chinatown, Grange Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Stn A PO Boxes
# First Canadian Place, Underground city
# Christie
# Queen's Park, Ontario Provincial Government

# %% [markdown]
# #### Show the size of the resulting dataframe and the unique categories which can be curated from all the returned venues

# %%
print(toronto_venues.shape)
toronto_venues.groupby('Neighborhood').count()
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# (517, 7)
# There are 147 uniques categories.

# %% [markdown]
# ## 4. Analyze the Neighborhoods in Downtown Toronto

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

cols_to_move = ['Yoga Studio']
new_cols = np.hstack((toronto_onehot.columns.difference(cols_to_move), cols_to_move))
# OPTION 1: reindex
toronto_onehot=toronto_onehot.reindex(columns=new_cols)


toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()


def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]



num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park              Beer Bar
# 1  CN Tower, King and Spadina, Railway Lands, Har...        Airport Lounge
# 2                                 Central Bay Street           Coffee Shop
# 3                                           Christie         Grocery Store
# 4                               Church and Wellesley                  Café
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop    Seafood Restaurant          Cocktail Bar
# 1       Airport Service      Airport Terminal               Airport
# 2                  Café    Seafood Restaurant        Sandwich Place
# 3                  Café                  Park    Italian Restaurant
# 4          Dance Studio            Smoke Shop     Indian Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0     French Restaurant        Breakfast Spot              Creperie
# 1                 Plane              Boutique           Coffee Shop
# 2      Ramen Restaurant            Poke Place       Bubble Tea Shop
# 3             Nightclub           Candy Store            Restaurant
# 4   Japanese Restaurant    Salon / Barbershop             Bookstore
#
#   8th Most Common Venue 9th Most Common Venue      10th Most Common Venue
# 0          Liquor Store                Bistro                Concert Hall
# 1                   Bar      Sculpture Garden               Boat or Ferry
# 2                  Park    Chinese Restaurant  Modern European Restaurant
# 3                 Diner            Baby Store          Athletics & Sports
# 4            Restaurant             Juice Bar            Ramen Restaurant

# %% [markdown]
# ## 5. Clustering the Neighborhoods and visualize the clusters on map

# %% [markdown]
# #### Run *k*-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 2, 0, 3, 4, 0, 0, 4, 4, 4], dtype=int32)

# %% [markdown]
# #### Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df_3

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#   Postal Code           Borough                 Neighborhood   Latitude  \
# 0         M4W  Downtown Toronto                     Rosedale  43.679563
# 1         M4X  Downtown Toronto  St. James Town, Cabbagetown  43.667967
# 2         M4Y  Downtown Toronto         Church and Wellesley  43.665860
# 3         M5A  Downtown Toronto    Regent Park, Harbourfront  43.654260
# 4         M5B  Downtown Toronto     Garden District, Ryerson  43.657162
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.377529               1                  Park            Playground
# 1 -79.367675               0            Restaurant    Italian Restaurant
# 2 -79.383160               4                  Café          Dance Studio
# 3 -79.360636               0           Coffee Shop                  Park
# 4 -79.378937               4                  Café               Theater
#
#   3rd Most Common Venue    4th Most Common Venue 5th Most Common Venue  \
# 0                 Trail  Comfort Food Restaurant         Deli / Bodega
# 1           Coffee Shop                     Café                Bakery
# 2            Smoke Shop        Indian Restaurant   Japanese Restaurant
# 3        Breakfast Spot                  Theater                Bakery
# 4           Coffee Shop             Burger Joint     Electronics Store
#
#   6th Most Common Venue  7th Most Common Venue 8th Most Common Venue  \
# 0          Dance Studio               Creperie        Cosmetics Shop
# 1          Liquor Store      Indian Restaurant   Japanese Restaurant
# 2    Salon / Barbershop              Bookstore            Restaurant
# 3           Event Space  Performing Arts Venue                  Café
# 4         Shopping Mall            Music Venue                 Plaza
#
#   9th Most Common Venue 10th Most Common Venue
# 0          Concert Hall             Comic Shop
# 1         Deli / Bodega          Jewelry Store
# 2             Juice Bar       Ramen Restaurant
# 3                   Pub             Restaurant
# 4      Ramen Restaurant                  Hotel

# %% [markdown]
# #### Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters_DT = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters_DT)
       
map_clusters_DT
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### **PLEASE VIEW THE VISUALIZED MAP BY DROP THE GITHUB LINK TO THIS .ipynb FILE INTO https://nbviewer.jupyter.org/**

# %% [markdown]
# ## 6. Examine Clusters

# %% [markdown]
# #### Cluster 0 (Red) Gastronomy

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                    Neighborhood  Cluster Labels  \
# 1                   St. James Town, Cabbagetown               0
# 3                     Regent Park, Harbourfront               0
# 7                            Central Bay Street               0
# 8                      Richmond, Adelaide, King               0
# 10     Toronto Dominion Centre, Design Exchange               0
# 11               Commerce Court, Victoria Hotel               0
# 16       First Canadian Place, Underground city               0
# 18  Queen's Park, Ontario Provincial Government               0
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 1             Restaurant    Italian Restaurant           Coffee Shop
# 3            Coffee Shop                  Park        Breakfast Spot
# 7            Coffee Shop                  Café    Seafood Restaurant
# 8            Coffee Shop                  Café           Pizza Place
# 10           Coffee Shop                  Café            Restaurant
# 11                  Café             Gastropub            Restaurant
# 16                  Café           Coffee Shop            Restaurant
# 18           Coffee Shop      Sushi Restaurant           Yoga Studio
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 1                   Café                Bakery          Liquor Store
# 3                Theater                Bakery           Event Space
# 7         Sandwich Place      Ramen Restaurant            Poke Place
# 8       Sushi Restaurant          Concert Hall                Lounge
# 10   Japanese Restaurant                 Hotel                Museum
# 11   Japanese Restaurant           Coffee Shop         Deli / Bodega
# 16    Seafood Restaurant              Tea Room            Steakhouse
# 18                 Diner                   Bar         Smoothie Shop
#
#     7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 1       Indian Restaurant   Japanese Restaurant         Deli / Bodega
# 3   Performing Arts Venue                  Café                   Pub
# 7         Bubble Tea Shop                  Park    Chinese Restaurant
# 8     Japanese Restaurant  Colombian Restaurant    Seafood Restaurant
# 10              Gastropub                   Pub          Concert Hall
# 11         Sandwich Place    Seafood Restaurant                   Pub
# 16              Gastropub                   Pub             Bookstore
# 18               Beer Bar   Distribution Center        Sandwich Place
#
#         10th Most Common Venue
# 1                Jewelry Store
# 3                   Restaurant
# 7   Modern European Restaurant
# 8                Deli / Bodega
# 10               Deli / Bodega
# 11              Ice Cream Shop
# 16               Deli / Bodega
# 18          Italian Restaurant

# %% [markdown]
# #### Cluster 1 (Purple) Nature

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#   Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0     Rosedale               1                  Park            Playground
#
#   3rd Most Common Venue    4th Most Common Venue 5th Most Common Venue  \
# 0                 Trail  Comfort Food Restaurant         Deli / Bodega
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0          Dance Studio              Creperie        Cosmetics Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 0          Concert Hall             Comic Shop

# %% [markdown]
# #### Cluster 2 (Blue) Transportation Hub

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                          Neighborhood  Cluster Labels  \
# 14  CN Tower, King and Spadina, Railway Lands, Har...               2
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 14        Airport Lounge       Airport Service      Airport Terminal
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 14               Airport                 Plane              Boutique
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 14           Coffee Shop                   Bar      Sculpture Garden
#
#    10th Most Common Venue
# 14          Boat or Ferry

# %% [markdown]
# #### Cluster 3 (Green) Miscellaneous

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 17     Christie               3         Grocery Store                  Café
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 17                  Park    Italian Restaurant             Nightclub
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 17           Candy Store            Restaurant                 Diner
#
#    9th Most Common Venue 10th Most Common Venue
# 17            Baby Store     Athletics & Sports

# %% [markdown]
# #### Cluster 4 (Yellow) Entertainment & Accommodation

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#                                          Neighborhood  Cluster Labels  \
# 2                                Church and Wellesley               4
# 4                            Garden District, Ryerson               4
# 5                                      St. James Town               4
# 6                                         Berczy Park               4
# 9   Harbourfront East, Union Station, Toronto Islands               4
# 12                     University of Toronto, Harbord               4
# 13          Kensington Market, Chinatown, Grange Park               4
# 15                                     Stn A PO Boxes               4
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 2                   Café          Dance Studio            Smoke Shop
# 4                   Café               Theater           Coffee Shop
# 5              Gastropub                  Café          Cocktail Bar
# 6               Beer Bar           Coffee Shop    Seafood Restaurant
# 9                  Plaza                  Park                 Hotel
# 12                  Café             Bookstore            Restaurant
# 13                  Café    Mexican Restaurant                Bakery
# 15                  Café            Restaurant    Seafood Restaurant
#
#     4th Most Common Venue    5th Most Common Venue    6th Most Common Venue  \
# 2       Indian Restaurant      Japanese Restaurant       Salon / Barbershop
# 4            Burger Joint        Electronics Store            Shopping Mall
# 5             Coffee Shop                BBQ Joint  New American Restaurant
# 6            Cocktail Bar        French Restaurant           Breakfast Spot
# 9      Italian Restaurant                   Lounge                Roof Deck
# 12                    Bar                   Bakery      Japanese Restaurant
# 13  Vietnamese Restaurant  Comfort Food Restaurant              Record Shop
# 15               Beer Bar             Cocktail Bar                Jazz Club
#
#    7th Most Common Venue      8th Most Common Venue 9th Most Common Venue  \
# 2              Bookstore                 Restaurant             Juice Bar
# 4            Music Venue                      Plaza      Ramen Restaurant
# 5                   Park  Middle Eastern Restaurant            Restaurant
# 6               Creperie               Liquor Store                Bistro
# 9            Salad Place            Bubble Tea Shop   Japanese Restaurant
# 12    Italian Restaurant                Yoga Studio          Dessert Shop
# 13           Pizza Place                Cheese Shop       Organic Grocery
# 15                 Hotel                       Park           Cheese Shop
#
#    10th Most Common Venue
# 2        Ramen Restaurant
# 4                   Hotel
# 5          Cosmetics Shop
# 6            Concert Hall
# 9            Skating Rink
# 12               Beer Bar
# 13           Cocktail Bar
# 15                 Museum

# %% [markdown]
# # THANK YOU FOR YOUR REVIEW!
