# %% [markdown]
# # Segmentation and Clustering the Neighborhoods in New York City

# %% [markdown]
# ## 1. Before we start to collect the data and exploring it, let's download all the dependencies that we will need.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# ## 2. Download and read the dataset of the neighborhoods in New York City and transform it into a *pandas* dataframe

# %% [markdown]
# #### Download and open the New York City data in JSON format

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')

with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)
# Out:
# Data downloaded!

# %% [markdown]
# #### Transform the New York City data into dataframe

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

neighborhoods_data = newyork_data['features']
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %% [markdown]
# #### Manhattan is selected for this project in the New York City

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data.head()
# Out:
#      Borough        Neighborhood   Latitude  Longitude
# 0  Manhattan         Marble Hill  40.876551 -73.910660
# 1  Manhattan           Chinatown  40.715618 -73.994279
# 2  Manhattan  Washington Heights  40.851903 -73.936900
# 3  Manhattan              Inwood  40.867684 -73.921210
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688

# %% [markdown]
# ## 3. Use the Foursquare API to explore neighbourhoods in Manhattan, New York City

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Manhattan, New York City, then visualize Manhattan the neighbourhoods in it by creating a map using **Folium**

# %%
address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Manhattan are {}, {}.'.format(latitude, longitude))

# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# The geograpical coordinate of Manhattan are 40.7896239, -73.9598939.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### **PLEASE VIEW THE VISUALIZED MAP BY DROP THE GITHUB LINK TO THIS .ipynb FILE INTO https://nbviewer.jupyter.org/**

# %% [markdown]
# #### Define Foursquare Credentials and Version.

# %%
CLIENT_ID = 'QR24W0AJYVEDYGP3OAWVWXEGVBW1X2NYSY5ZM0WW34I10AF2' # your Foursquare ID
CLIENT_SECRET = 'MMSVAVCUUGDAQKKD3R2HLDI4OMUEUCZVGUCCGUREXKY34WTZ' # your Foursquare Secret
VERSION = '20200517' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QR24W0AJYVEDYGP3OAWVWXEGVBW1X2NYSY5ZM0WW34I10AF2
# CLIENT_SECRET:MMSVAVCUUGDAQKKD3R2HLDI4OMUEUCZVGUCCGUREXKY34WTZ

# %% [markdown]
# #### Explore the neighborhoods in Manhattan. Create GET request URL, send the GET request, then clean and structure json into a new dataframe

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        
        LIMIT = 100 # limit of number of venues returned by Foursquare API
        radius = 500 # define radius
        
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude']
                                  )
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards

# %% [markdown]
# #### Show the size of the resulting dataframe and the unique categories which can be curated from all the returned venues

# %%
print(manhattan_venues.shape)
manhattan_venues.groupby('Neighborhood').count()
print('There are {} uniques categories.'.format(len(manhattan_venues['Venue Category'].unique())))
# Out:
# (3062, 7)
# There are 332 uniques categories.

# %% [markdown]
# ## 4. Analyze the Neighborhoods in Manhattan

# %%
# one hot encoding
manhattan_onehot = pd.get_dummies(manhattan_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
manhattan_onehot['Neighborhood'] = manhattan_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [manhattan_onehot.columns[-1]] + list(manhattan_onehot.columns[:-1])
manhattan_onehot = manhattan_onehot[fixed_columns]


# group rows by neighborhood and by taking the mean of the frequency of occurrence of each category
manhattan_grouped = manhattan_onehot.groupby('Neighborhood').mean().reset_index()


# write a function to sort the venues in descending order
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]


# create the new dataframe and display the top 10 venues for each neighborhood
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = manhattan_grouped['Neighborhood']

for ind in np.arange(manhattan_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(manhattan_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0  Battery Park City                  Park           Coffee Shop
# 1      Carnegie Hill           Coffee Shop           Pizza Place
# 2     Central Harlem    African Restaurant   Fried Chicken Joint
# 3            Chelsea           Art Gallery           Coffee Shop
# 4          Chinatown    Chinese Restaurant          Cocktail Bar
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                 Hotel         Memorial Site                   Gym
# 1           Yoga Studio                   Gym             Wine Shop
# 2   American Restaurant                   Bar        Cosmetics Shop
# 3                  Café        Ice Cream Shop   American Restaurant
# 4       Bubble Tea Shop                Bakery           Coffee Shop
#
#   6th Most Common Venue  7th Most Common Venue 8th Most Common Venue  \
# 0         Boat or Ferry           Gourmet Shop            Food Court
# 1                   Bar              Bookstore                  Café
# 2     French Restaurant     Seafood Restaurant    Chinese Restaurant
# 3                Market     Seafood Restaurant              Boutique
# 4    Salon / Barbershop  Vietnamese Restaurant          Optical Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 0         Shopping Mall              Wine Shop
# 1   Japanese Restaurant          Grocery Store
# 2                  Café       Tapas Restaurant
# 3          Cupcake Shop           Cycle Studio
# 4   American Restaurant                    Spa

# %% [markdown]
# ## 5. Clustering the Neighborhoods and visualize the clusters on map

# %% [markdown]
# #### Run *k*-means to cluster the neighborhood into 5 clusters.

# %%
# set number of clusters
kclusters = 5

manhattan_grouped_clustering = manhattan_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(manhattan_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 1, 0, 2, 0, 2, 2, 0, 0, 2], dtype=int32)

# %% [markdown]
# #### Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

manhattan_merged = manhattan_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
manhattan_merged = manhattan_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

manhattan_merged.head() # check the last columns!
# Out:
#      Borough        Neighborhood   Latitude  Longitude  Cluster Labels  \
# 0  Manhattan         Marble Hill  40.876551 -73.910660               2
# 1  Manhattan           Chinatown  40.715618 -73.994279               0
# 2  Manhattan  Washington Heights  40.851903 -73.936900               1
# 3  Manhattan              Inwood  40.867684 -73.921210               1
# 4  Manhattan    Hamilton Heights  40.823604 -73.949688               1
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0        Sandwich Place           Coffee Shop                   Gym
# 1    Chinese Restaurant          Cocktail Bar       Bubble Tea Shop
# 2                  Café                Bakery           Pizza Place
# 3    Mexican Restaurant                  Café                Lounge
# 4           Pizza Place           Coffee Shop                  Café
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0        Ice Cream Shop      Department Store              Pharmacy
# 1                Bakery           Coffee Shop    Salon / Barbershop
# 2     Mobile Phone Shop    Chinese Restaurant         Grocery Store
# 3           Pizza Place            Restaurant         Deli / Bodega
# 4         Deli / Bodega    Mexican Restaurant          Cocktail Bar
#
#        7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0                      Diner        Discount Store            Donut Shop
# 1      Vietnamese Restaurant          Optical Shop   American Restaurant
# 2  Latin American Restaurant            Donut Shop        Sandwich Place
# 3         Chinese Restaurant    Spanish Restaurant  Caribbean Restaurant
# 4          Indian Restaurant      Sushi Restaurant                  Park
#
#   10th Most Common Venue
# 0                   Bank
# 1                    Spa
# 2        Supplement Shop
# 3                   Park
# 4            Yoga Studio

# %% [markdown]
# #### Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters_MH = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters_MH)
       
map_clusters_MH
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### **PLEASE VIEW THE VISUALIZED MAP BY DROP THE GITHUB LINK TO THIS .ipynb FILE INTO https://nbviewer.jupyter.org/**

# %% [markdown]
# ## Examine Clusters

# %% [markdown]
# #### Cluster 0 (Red) Miscellaneous/Night Life

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 0, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 1         Chinatown    Chinese Restaurant          Cocktail Bar
# 6    Central Harlem    African Restaurant   Fried Chicken Joint
# 7       East Harlem    Mexican Restaurant                Bakery
# 19     East Village          Cocktail Bar           Pizza Place
# 20  Lower East Side    Chinese Restaurant                  Park
# 22     Little Italy       Bubble Tea Shop    Chinese Restaurant
#
#         3rd Most Common Venue 4th Most Common Venue     5th Most Common Venue  \
# 1             Bubble Tea Shop                Bakery               Coffee Shop
# 6         American Restaurant                   Bar            Cosmetics Shop
# 7   Latin American Restaurant       Thai Restaurant             Deli / Bodega
# 19         Mexican Restaurant           Coffee Shop                       Bar
# 20               Cocktail Bar                  Café          Ramen Restaurant
# 22                     Bakery                   Spa  Mediterranean Restaurant
#
#    6th Most Common Venue  7th Most Common Venue  8th Most Common Venue  \
# 1     Salon / Barbershop  Vietnamese Restaurant           Optical Shop
# 6      French Restaurant     Seafood Restaurant     Chinese Restaurant
# 7             Restaurant               Beer Bar      French Restaurant
# 19             Juice Bar               Wine Bar    Japanese Restaurant
# 20           Art Gallery               Pet Café  Performing Arts Venue
# 22    Italian Restaurant        Thai Restaurant                  Hotel
#
#    9th Most Common Venue 10th Most Common Venue
# 1    American Restaurant                    Spa
# 6                   Café       Tapas Restaurant
# 7           Liquor Store             Steakhouse
# 19      Ramen Restaurant              Speakeasy
# 20              Pharmacy         Ice Cream Shop
# 22        Ice Cream Shop            Coffee Shop

# %% [markdown]
# #### Cluster 1 (Purple) Gastronomy

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 1, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#           Neighborhood 1st Most Common Venue     2nd Most Common Venue  \
# 2   Washington Heights                  Café                    Bakery
# 3               Inwood    Mexican Restaurant                      Café
# 4     Hamilton Heights           Pizza Place               Coffee Shop
# 5       Manhattanville           Coffee Shop        Seafood Restaurant
# 9            Yorkville    Italian Restaurant               Coffee Shop
# 10          Lenox Hill           Coffee Shop        Italian Restaurant
# 12     Upper West Side    Italian Restaurant               Coffee Shop
# 18   Greenwich Village    Italian Restaurant               Coffee Shop
# 23                Soho    Italian Restaurant  Mediterranean Restaurant
# 25    Manhattan Valley           Coffee Shop                       Spa
# 27            Gramercy    Italian Restaurant                       Bar
# 30       Carnegie Hill           Coffee Shop               Pizza Place
# 31                Noho    Italian Restaurant               Coffee Shop
# 35          Turtle Bay           Coffee Shop                      Park
# 36          Tudor City                  Café                      Park
#
#    3rd Most Common Venue 4th Most Common Venue      5th Most Common Venue  \
# 2            Pizza Place     Mobile Phone Shop         Chinese Restaurant
# 3                 Lounge           Pizza Place                 Restaurant
# 4                   Café         Deli / Bodega         Mexican Restaurant
# 5     Italian Restaurant         Deli / Bodega                       Park
# 9                    Gym      Sushi Restaurant                        Bar
# 10           Pizza Place                  Café           Sushi Restaurant
# 12          Dessert Shop                   Bar  Middle Eastern Restaurant
# 18                  Café                   Gym          Indian Restaurant
# 23           Coffee Shop        Sandwich Place          French Restaurant
# 25           Pizza Place                   Bar         Mexican Restaurant
# 27           Coffee Shop            Playground                Pizza Place
# 30           Yoga Studio                   Gym                  Wine Shop
# 31           Pizza Place   Japanese Restaurant              Grocery Store
# 35    Italian Restaurant                  Café              Deli / Bodega
# 36    Mexican Restaurant         Deli / Bodega                      Diner
#
#    6th Most Common Venue      7th Most Common Venue     8th Most Common Venue  \
# 2          Grocery Store  Latin American Restaurant                Donut Shop
# 3          Deli / Bodega         Chinese Restaurant        Spanish Restaurant
# 4           Cocktail Bar          Indian Restaurant          Sushi Restaurant
# 5       Sushi Restaurant         Mexican Restaurant                      Café
# 9          Deli / Bodega         Mexican Restaurant       Japanese Restaurant
# 10          Cocktail Bar       Gym / Fitness Center                       Gym
# 12             Bookstore           Sushi Restaurant  Mediterranean Restaurant
# 18        Ice Cream Shop                     Bakery               Comedy Club
# 23        Clothing Store                        Gym                    Bakery
# 25         Grocery Store                 Playground                      Park
# 27    Mexican Restaurant              Grocery Store                Bagel Shop
# 30                   Bar                  Bookstore                      Café
# 31        Sandwich Place         Mexican Restaurant                 Wine Shop
# 35    Seafood Restaurant                   Wine Bar          Sushi Restaurant
# 36           Pizza Place                    Dog Run          Asian Restaurant
#
#    9th Most Common Venue     10th Most Common Venue
# 2         Sandwich Place            Supplement Shop
# 3   Caribbean Restaurant                       Park
# 4                   Park                Yoga Studio
# 5             Bike Trail                   Boutique
# 9                  Diner                  Wine Shop
# 10          Burger Joint                Salad Place
# 12           Pizza Place                     Bakery
# 18        Clothing Store               Gourmet Shop
# 23                  Café                        Spa
# 25          Noodle House  Latin American Restaurant
# 27        Ice Cream Shop                      Diner
# 30   Japanese Restaurant              Grocery Store
# 31             Gift Shop                   Tea Room
# 35     French Restaurant                Karaoke Bar
# 36                   Bar                     Garden

# %% [markdown]
# #### Cluster 2 (Blue) Entertainment & Accommodation

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 2, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#            Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0           Marble Hill        Sandwich Place           Coffee Shop
# 8       Upper East Side    Italian Restaurant                Bakery
# 13       Lincoln Square    Italian Restaurant                  Café
# 14              Clinton               Theater           Coffee Shop
# 15              Midtown           Coffee Shop                 Hotel
# 16          Murray Hill                 Hotel        Sandwich Place
# 17              Chelsea           Art Gallery           Coffee Shop
# 21              Tribeca    Italian Restaurant                  Park
# 24         West Village    Italian Restaurant   American Restaurant
# 26  Morningside Heights                  Park           Coffee Shop
# 28    Battery Park City                  Park           Coffee Shop
# 29   Financial District           Coffee Shop                 Hotel
# 32         Civic Center     French Restaurant           Coffee Shop
# 33        Midtown South     Korean Restaurant                 Hotel
# 34         Sutton Place    Italian Restaurant           Coffee Shop
# 38             Flatiron  Gym / Fitness Center    Italian Restaurant
# 39         Hudson Yards                 Hotel  Gym / Fitness Center
#
#    3rd Most Common Venue    4th Most Common Venue 5th Most Common Venue  \
# 0                    Gym           Ice Cream Shop      Department Store
# 8   Gym / Fitness Center                      Spa   American Restaurant
# 13                 Plaza     Gym / Fitness Center               Theater
# 14  Gym / Fitness Center                    Hotel                   Gym
# 15               Theater              Pizza Place      Cuban Restaurant
# 16           Coffee Shop     Gym / Fitness Center            Steakhouse
# 17                  Café           Ice Cream Shop   American Restaurant
# 21              Wine Bar                     Café                   Spa
# 24              Wine Bar  New American Restaurant           Coffee Shop
# 26             Bookstore      American Restaurant         Deli / Bodega
# 28                 Hotel            Memorial Site                   Gym
# 29           Pizza Place      American Restaurant        Sandwich Place
# 32   American Restaurant                     Park                 Hotel
# 33   Japanese Restaurant             Burger Joint                  Café
# 34  Gym / Fitness Center                      Gym                  Park
# 38    Salon / Barbershop                Wine Shop                  Park
# 39   American Restaurant                     Café    Italian Restaurant
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                Pharmacy                 Diner        Discount Store
# 8                 Exhibit                 Hotel             Juice Bar
# 13  Performing Arts Venue          Concert Hall             Wine Shop
# 14     Italian Restaurant             Wine Shop        Sandwich Place
# 15                 Bakery   Japanese Restaurant        Clothing Store
# 16    Japanese Restaurant           Pizza Place    Chinese Restaurant
# 17                 Market    Seafood Restaurant              Boutique
# 21                  Hotel           Coffee Shop                Bakery
# 24              Jazz Club                Bakery                  Park
# 26           Burger Joint        Sandwich Place          Tennis Court
# 28          Boat or Ferry          Gourmet Shop            Food Court
# 29            Salad Place  Gym / Fitness Center             Juice Bar
# 32                    Spa      Sushi Restaurant  Gym / Fitness Center
# 33            Coffee Shop             Hotel Bar  Gym / Fitness Center
# 34             Bagel Shop                 Hotel                Bakery
# 38      Outdoor Sculpture        Cosmetics Shop                   Gym
# 39             Restaurant                  Park                   Gym
#
#       9th Most Common Venue    10th Most Common Venue
# 0                Donut Shop                      Bank
# 8               Yoga Studio                 Wine Shop
# 13        French Restaurant             Grocery Store
# 14                      Spa       American Restaurant
# 15           Cosmetics Shop                       Spa
# 16        Indian Restaurant                 Juice Bar
# 17             Cupcake Shop              Cycle Studio
# 21               Steakhouse          Greek Restaurant
# 24             Cocktail Bar               Pizza Place
# 26  New American Restaurant               Supermarket
# 28            Shopping Mall                 Wine Shop
# 29                     Café              Cocktail Bar
# 32              Yoga Studio                 Wine Shop
# 33                   Lounge              Dessert Shop
# 34   Furniture / Home Store             Grocery Store
# 38            Grocery Store  Mediterranean Restaurant
# 39            Boat or Ferry               Coffee Shop

# %% [markdown]
# #### Cluster 3 (Green) Nature

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 3, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 11  Roosevelt Island            Playground                  Park
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 11                   Gym           Dry Cleaner      Greek Restaurant
#
#    6th Most Common Venue  7th Most Common Venue 8th Most Common Venue  \
# 11           Coffee Shop  Outdoors & Recreation        Sandwich Place
#
#    9th Most Common Venue 10th Most Common Venue
# 11        Scenic Lookout                 School

# %% [markdown]
# #### Cluster 4 (Yellow) Sport Hub

# %%
manhattan_merged.loc[manhattan_merged['Cluster Labels'] == 4, manhattan_merged.columns[[1] + list(range(5, manhattan_merged.shape[1]))]]
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 37  Stuyvesant Town                  Park            Playground
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 37           Gas Station                   Gym  Gym / Fitness Center
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 37        Baseball Field          Cocktail Bar       Harbor / Marina
#
#    9th Most Common Venue 10th Most Common Venue
# 37     German Restaurant                 Bistro

# %% [markdown]
# # Thank you for your review!
